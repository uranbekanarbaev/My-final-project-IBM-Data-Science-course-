# %% [markdown]
# <a href="https://colab.research.google.com/github/uranbekanarbaev/My-final-project-IBM-Data-Science-course-/blob/main/WebScrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance

# %%
import yfinance as yf
import requests
from bs4 import BeautifulSoup

# %%
tesla = yf.Ticker("TSLA")
tesla_data = tesla.history(period = "max")
tesla_data.head()
# Out:
#                                Open      High       Low     Close     Volume  \
# Date
# 2010-06-29 00:00:00-04:00  1.266667  1.666667  1.169333  1.592667  281494500
# 2010-06-30 00:00:00-04:00  1.719333  2.028000  1.553333  1.588667  257806500
# 2010-07-01 00:00:00-04:00  1.666667  1.728000  1.351333  1.464000  123282000
# 2010-07-02 00:00:00-04:00  1.533333  1.540000  1.247333  1.280000   77097000
# 2010-07-06 00:00:00-04:00  1.333333  1.333333  1.055333  1.074000  103003500
#
#                            Dividends  Stock Splits
# Date
# 2010-06-29 00:00:00-04:00        0.0           0.0
# 2010-06-30 00:00:00-04:00        0.0           0.0
# 2010-07-01 00:00:00-04:00        0.0           0.0
# 2010-07-02 00:00:00-04:00        0.0           0.0
# 2010-07-06 00:00:00-04:00        0.0           0.0

# %%
import requests
from bs4 import BeautifulSoup

# Define the URL to scrape
url = 'https://companiesmarketcap.com/tesla/revenue/#google_vignette'

# Send a GET request to the URL
response = requests.get(url)

# Parse the response content
soup = BeautifulSoup(response.content, 'html.parser')

# Find the revenue table by its class name
revenue_table = soup.find_all('tbody')[0]

# Check if the table is found
if revenue_table:
    # Extract the Tesla revenue data
    tesla_revenue_data = []
    for row in revenue_table.find_all('tr')[1:]:
        cells = row.find_all('td')
        if len(cells) > 0:
            date = cells[0].text
            revenue = cells[1].text.replace(',', '').replace('$', '')
            tesla_revenue_data.append({'date': date, 'revenue': revenue})

    # Print the extracted data
    for data in tesla_revenue_data:
        print(f"Date: {data['date']} Revenue: {data['revenue']}")
else:
    print("Revenue table not found!")

tesla_df_revenue = pd.json_normalize(tesla_revenue_data)
tesla_df_revenue
# Out:
# Date: 2022  Revenue: 81.46 B
# Date: 2021  Revenue: 53.82 B
# Date: 2020  Revenue: 31.53 B
# Date: 2019  Revenue: 24.57 B
# Date: 2018  Revenue: 21.46 B
# Date: 2017  Revenue: 11.75 B
# Date: 2016  Revenue: 7.00 B
# Date: 2015  Revenue: 4.04 B
# Date: 2014  Revenue: 3.19 B
# Date: 2013  Revenue: 2.01 B
# Date: 2012  Revenue: 0.41 B
# Date: 2011  Revenue: 0.20 B
# Date: 2010  Revenue: 0.11 B
# Date: 2009  Revenue: 0.11 B
#      date  revenue
# 0   2022   81.46 B
# 1   2021   53.82 B
# 2   2020   31.53 B
# 3   2019   24.57 B
# 4   2018   21.46 B
# 5   2017   11.75 B
# 6   2016    7.00 B
# 7   2015    4.04 B
# 8   2014    3.19 B
# 9   2013    2.01 B
# 10  2012    0.41 B
# 11  2011    0.20 B
# 12  2010    0.11 B
# 13  2009    0.11 B

# %%
gamestop = yf.Ticker('GME')
gamestop_data = gamestop.history(period='max')
gamestop_data
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2002-02-13 00:00:00-05:00   1.620128   1.693350   1.603296   1.691666
# 2002-02-14 00:00:00-05:00   1.712707   1.716074   1.670626   1.683250
# 2002-02-15 00:00:00-05:00   1.683250   1.687458   1.658001   1.674834
# 2002-02-19 00:00:00-05:00   1.666418   1.666418   1.578047   1.607504
# 2002-02-20 00:00:00-05:00   1.615921   1.662210   1.603296   1.662210
# ...                              ...        ...        ...        ...
# 2024-05-01 00:00:00-04:00  11.030000  11.320000  10.700000  10.910000
# 2024-05-02 00:00:00-04:00  11.110000  12.880000  10.960000  12.760000
# 2024-05-03 00:00:00-04:00  12.420000  17.450001  12.310000  16.469999
# 2024-05-06 00:00:00-04:00  14.990000  17.400000  13.620000  16.309999
# 2024-05-07 00:00:00-04:00  15.850000  17.290001  14.930000  16.309999
#
#                              Volume  Dividends  Stock Splits
# Date
# ...

# %%
import requests
from bs4 import BeautifulSoup

# Define the URL to scrape
url = 'https://companiesmarketcap.com/gamestop/revenue/'

# Send a GET request to the URL
response = requests.get(url)

# Parse the response content
soup = BeautifulSoup(response.content, 'html.parser')

# Find the revenue table by its class name
gamestop_revenue_table = soup.find_all('tbody')[0]

# Check if the table is found
if gamestop_revenue_table:
    # Extract the Tesla revenue data
    gamestop_revenue_data = []
    for row in gamestop_revenue_table.find_all('tr')[1:]:
        cells = row.find_all('td')
        if len(cells) > 0:
            date = cells[0].text
            revenue = cells[1].text.replace(',', '').replace('$', '')
            gamestop_revenue_data.append({'date': date, 'revenue': revenue})

    # Print the extracted data
    print(gamestop_revenue_data)
else:
    print("Revenue table not found!")

gamestop_df_revenue = pd.json_normalize(gamestop_revenue_data)
gamestop_df_revenue
# Out:
# [{'date': '2023 ', 'revenue': '5.70 B'}, {'date': '2022 ', 'revenue': '5.95 B'}, {'date': '2021 ', 'revenue': '5.87 B'}, {'date': '2020 ', 'revenue': '5.16 B'}, {'date': '2019 ', 'revenue': '6.89 B'}, {'date': '2018 ', 'revenue': '8.72 B'}, {'date': '2017 ', 'revenue': '8.76 B'}, {'date': '2016 ', 'revenue': '9.08 B'}, {'date': '2015 ', 'revenue': '9.31 B'}, {'date': '2014 ', 'revenue': '9.50 B'}, {'date': '2013 ', 'revenue': '8.91 B'}, {'date': '2012 ', 'revenue': '8.90 B'}, {'date': '2011 ', 'revenue': '9.66 B'}, {'date': '2010 ', 'revenue': '9.30 B'}, {'date': '2009 ', 'revenue': '9.04 B'}, {'date': '2008 ', 'revenue': '8.17 B'}, {'date': '2007 ', 'revenue': '6.53 B'}, {'date': '2006 ', 'revenue': '4.68 B'}, {'date': '2005 ', 'revenue': '2.13 B'}, {'date': '2004 ', 'revenue': '1.75 B'}, {'date': '2003 ', 'revenue': '1.47 B'}, {'date': '2002 ', 'revenue': '1.34 B'}]
#      date revenue
# 0   2023   5.70 B
# 1   2022   5.95 B
# 2   2021   5.87 B
# 3   2020   5.16 B
# ...
